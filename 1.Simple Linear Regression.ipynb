# %% [markdown]
# # 1.import the Necessary Library:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Read & Load of the dataset:

# %%
df = pd.read_csv("HeightWeight.csv")

# %%
df.head()
# Out:
#    Weight   Height
# 0       45     120
# 1       58     135
# 2       48     123
# 3       60     145
# 4       70     160

# %% [markdown]
# # Visualize the Data:

# %%
plt.scatter(df["Weight "], df['Height'])
plt.xlabel("Weight")
plt.ylabel("Height")
# Out:
# Text(0, 0.5, 'Height')

# %%
x = df.iloc[:,0:1]
y = df.iloc[:,-1]

# %%
x
# Out:
#     Weight
# 0        45
# 1        58
# 2        48
# 3        60
# 4        70
# 5        78
# 6        80
# 7        90
# 8        95
# 9        78
# 10       82
# 11       95
# 12      105
# 13      100
# 14       85
# 15       78
# 16       50
# 17       65
# 18       76
# 19       87
# 20       45
# 21       56
# 22       72

# %%
y
# Out:
# 0     120
# 1     135
# 2     123
# 3     145
# 4     160
# 5     162
# 6     163
# 7     175
# 8     182
# 9     170
# 10    176
# 11    182
# 12    175
# 13    183
# 14    170
# 15    177
# 16    140
# 17    159
# 18    150
# 19    167
# 20    129
# 21    140
# 22    160
# Name: Height, dtype: int64

# %%
df.shape
# Out:
# (23, 2)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size = 0.2, random_state = 2)

# %%
from sklearn.linear_model import LinearRegression

# %%
reg = LinearRegression()

# %%
reg
# Out:
# LinearRegression()

# %%
reg.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
x_test
# Out:
#     Weight
# 20       45
# 0        45
# 21       56
# 6        80
# 14       85

# %%
y_test
# Out:
# 20    129
# 0     120
# 21    140
# 6     163
# 14    170
# Name: Height, dtype: int64

# %%
reg.predict(x_test.iloc[0].values.reshape(1,1))
# Out:
# C:\Users\VISHAL KUMAR SWAIN\AppData\Roaming\Python\Python39\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([131.718363])

# %%
reg.predict(x_test.iloc[4].values.reshape(1,1))
# Out:
# C:\Users\VISHAL KUMAR SWAIN\AppData\Roaming\Python\Python39\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([169.85142823])

# %%
m = reg.coef_

# %%
m
# Out:
# array([0.95332663])

# %%
b = reg.intercept_

# %%
b
# Out:
# 88.81866461647641

# %% [markdown]
# # Equation => y = mx + b

# %%
y = m * 45 + b

# %%
y
# Out:
# array([131.718363])

# %%
plt.scatter(df["Weight "], df['Height'])
plt.plot(x_train.values,reg.predict(x_train), color ='green')
plt.xlabel("Weight")
plt.ylabel("Height")
# Out:
# Text(0, 0.5, 'Height')
